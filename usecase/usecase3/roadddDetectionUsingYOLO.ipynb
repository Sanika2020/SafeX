# %% [markdown]
# <a href="https://colab.research.google.com/github/mounishvatti/pothole_detection_yolov8/blob/main/PotholeDetectionUsingYOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
import glob

# %%
from IPython.display import Image, display

# %%
# !nvidia-smi
# Out:
# Mon Oct 30 19:23:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
HOME = os.getcwd()

# %%
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.203-py3-none-any.whl (644 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.0+cu118)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.16.0+cu118)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.0.203

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.6/78.2 GB disk)

# %%
# !mkdir {HOME}/datasets
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists

# %%
# %cd {HOME}/datasets
# Out:
# /content/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="QUWMCW70c1dPy9pc03sQ")
project = rf.workspace("hiteshram").project("object-detection-bounding-box-ftfs5")
dataset = project.version(1).download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.10/dist-packages (1.1.7)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Requirement already satisfied: opencv-python-headless==4.8.0.74 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.8.0.74)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: supervision in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.7)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.43.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.1)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Object-Detection-(Bounding-Box)-1 to yolov5pytorch:: 100%|██████████| 28470/28470 [00:00<00:00, 45149.53it/s]
# Extracting Dataset Version Zip to Object-Detection-(Bounding-Box)-1 in yolov5pytorch:: 100%|██████████| 800/800 [00:00<00:00, 5737.57it/s]

# %%
# !pip install fastapi kaleido python_multipart uvicorn
# Out:
# Collecting fastapi
#   Downloading fastapi-0.104.1-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 2.1 MB/s eta 0:00:00
# Collecting kaleido
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.8 MB/s eta 0:00:00
# Collecting python_multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 kB 5.8 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.23.2-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi) (3.7.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (1.10.13)
# Collecting starlette<0.28.0,>=0.27.0 (from fastapi)
#   Downloading starlette-0.27.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 8.2 MB/s eta 0:00:00
# Collecting typing-extensions>=4.8.0 (from fastapi)
#   Downloading typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn) (8.1.7)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (2.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi) (1.1.3)
# Installing collected packages: kaleido, typing-extensions, python_multipart, h11, uvicorn, starlette, fastapi
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.8.0 which is incompatible.
# Successfully installed fastapi-0.104.1 h11-0.14.0 kaleido-0.2.1 python_multipart-0.0.6 starlette-0.27.0 typing-extensions-4.8.0 uvicorn-0.23.2

# %%
# %cd {HOME}
# Out:
# /content

# %%
# %cd {dataset.location}
# Out:
# /content/Object-Detection-(Bounding-Box)-1

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8m.pt data=/content/drive/MyDrive/potholedetection/data.yaml epochs=70 imgsz=640
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt to 'yolov8m.pt'...
# 100% 49.7M/49.7M [00:00<00:00, 235MB/s]
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=/content/drive/MyDrive/potholedetection/data.yaml, epochs=70, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, stream_buffer=False, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 14.5MB/s]
# 2023-10-30 19:27:39.760427: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-30 19:27:39.760482: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-30 19:27:39.760530: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 295 layers, 25856899 parameters, 25856883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.23M/6.23M [00:00<00:00, 71.9MB/s]
# AMP: checks passed ✅
# train: Scanning /content/drive/MyDrive/potholedetection/train/labels.cache... 77 images, 0 backgrounds, 0 corrupt: 100% 77/77 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/drive/MyDrive/potholedetection/valid/labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100% 11/11 [00:00<?, ?it/s]
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 70 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/70      6.79G      1.872      4.399      1.765         63        640: 100% 5/5 [00:10<00:00,  2.06s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all         11         44     0.0124     0.0455    0.00354    0.00191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/70       6.9G      1.677       2.81      1.618         82        640: 100% 5/5 [00:02<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.19it/s]
#                    all         11         44       0.29      0.364      0.212      0.105
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/70      6.94G       1.54      2.095      1.471         64        640: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.72it/s]
#                    all         11         44      0.445      0.201      0.176      0.092
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/70      7.08G       1.52       1.83      1.464         87        640: 100% 5/5 [00:02<00:00,  1.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.71it/s]
#                    all         11         44      0.305      0.136      0.111     0.0645
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/70      7.11G      1.502      1.713      1.473         48        640: 100% 5/5 [00:02<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.65it/s]
#                    all         11         44      0.102      0.205      0.049     0.0227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/70      7.08G      1.487      1.724      1.463         58        640: 100% 5/5 [00:02<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.11it/s]
#                    all         11         44      0.487      0.182      0.204     0.0967
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/70      7.12G      1.536      1.643      1.475         86        640: 100% 5/5 [00:02<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.80it/s]
#                    all         11         44      0.115      0.227     0.0764     0.0353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/70      7.11G       1.48      1.529      1.436        112        640: 100% 5/5 [00:02<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.93it/s]
#                    all         11         44     0.0621      0.364     0.0373     0.0155
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/70      7.09G       1.47      1.515       1.44        101        640: 100% 5/5 [00:02<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.68it/s]
#                    all         11         44     0.0283      0.318     0.0164    0.00583
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/70      7.09G      1.581      1.658      1.548         71        640: 100% 5/5 [00:02<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.03it/s]
#                    all         11         44    0.00826      0.341    0.00575    0.00205
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/70      7.09G      1.636      1.498      1.476         53        640: 100% 5/5 [00:02<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.58it/s]
#                    all         11         44    0.00709      0.136     0.0115      0.004
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/70      6.99G      1.564      1.408      1.426         40        640: 100% 5/5 [00:02<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.24it/s]
#                    all         11         44    0.00468      0.205    0.00247    0.00114
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/70       7.1G       1.44      1.487      1.452         66        640: 100% 5/5 [00:02<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all         11         44    0.00731      0.409    0.00621    0.00176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/70      7.14G      1.502      1.478      1.449         93        640: 100% 5/5 [00:02<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.43it/s]
#                    all         11         44    0.00748      0.386    0.00484    0.00187
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/70      7.14G      1.564      1.574      1.532         55        640: 100% 5/5 [00:02<00:00,  1.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.17it/s]
#                    all         11         44     0.0102       0.25     0.0059    0.00253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/70       7.1G      1.652      1.446      1.486         87        640: 100% 5/5 [00:02<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.25it/s]
#                    all         11         44     0.0206      0.318     0.0168     0.0056
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/70      7.01G      1.682      1.497       1.54         80        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.43it/s]
#                    all         11         44     0.0735      0.227     0.0344     0.0167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/70      7.01G      1.537      1.456      1.465         92        640: 100% 5/5 [00:02<00:00,  1.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.54it/s]
#                    all         11         44     0.0722      0.227      0.036     0.0174
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/70      6.93G      1.654      1.616      1.544         71        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.97it/s]
#                    all         11         44     0.0874      0.295     0.0457     0.0175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/70         7G      1.545      1.534      1.485         62        640: 100% 5/5 [00:02<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         11         44     0.0505      0.386     0.0335     0.0141
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/70      7.09G      1.613      1.657      1.548         58        640: 100% 5/5 [00:02<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.38it/s]
#                    all         11         44    0.00917      0.273    0.00552    0.00221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/70      7.09G      1.597      1.494       1.53         85        640: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.74it/s]
#                    all         11         44     0.0148     0.0682    0.00502    0.00221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/70      7.14G        1.6      1.587      1.534         79        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.84it/s]
#                    all         11         44    0.00993      0.114    0.00725    0.00316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/70      7.03G      1.533      1.484       1.44         75        640: 100% 5/5 [00:02<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.88it/s]
#                    all         11         44     0.0241      0.295     0.0267    0.00756
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/70      7.03G      1.581      1.525      1.505         99        640: 100% 5/5 [00:02<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.41it/s]
#                    all         11         44     0.0712      0.295      0.051     0.0167
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/70      7.12G      1.482      1.412      1.477        112        640: 100% 5/5 [00:02<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.12it/s]
#                    all         11         44      0.199      0.341      0.186     0.0817
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/70         7G      1.407      1.302      1.429         94        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.43it/s]
#                    all         11         44      0.253      0.318      0.254      0.134
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/70      6.97G      1.601      1.442      1.457         56        640: 100% 5/5 [00:02<00:00,  1.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.53it/s]
#                    all         11         44      0.327        0.5      0.371      0.191
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/70      6.99G      1.492      1.349      1.415         64        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.25it/s]
#                    all         11         44      0.182      0.455      0.183      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/70      6.99G      1.516      1.236      1.444         89        640: 100% 5/5 [00:02<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.04it/s]
#                    all         11         44     0.0518      0.614     0.0418     0.0215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/70      6.98G      1.427      1.276       1.38         60        640: 100% 5/5 [00:02<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.23it/s]
#                    all         11         44     0.0381      0.588      0.032     0.0178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/70      7.13G      1.431      1.234      1.419         75        640: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.40it/s]
#                    all         11         44     0.0545      0.545     0.0424     0.0222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/70      6.97G       1.35      1.159      1.326         71        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.25it/s]
#                    all         11         44     0.0837      0.523     0.0663     0.0361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/70      7.11G      1.347      1.127      1.374         63        640: 100% 5/5 [00:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.08it/s]
#                    all         11         44      0.202      0.523      0.202      0.111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/70       7.1G      1.408      1.212      1.362         69        640: 100% 5/5 [00:02<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.68it/s]
#                    all         11         44      0.451      0.409      0.336      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/70      7.15G      1.421      1.264      1.358         70        640: 100% 5/5 [00:02<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.03it/s]
#                    all         11         44      0.384      0.432      0.297      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/70      6.99G      1.374      1.117      1.353         86        640: 100% 5/5 [00:02<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.39it/s]
#                    all         11         44      0.446      0.384       0.35      0.176
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/70      7.03G      1.319      1.172      1.301         53        640: 100% 5/5 [00:02<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.04it/s]
#                    all         11         44      0.488      0.364      0.378      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/70      6.98G      1.268       1.13      1.319         59        640: 100% 5/5 [00:02<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.47it/s]
#                    all         11         44      0.517      0.545       0.45      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/70      7.05G      1.283       1.12      1.321         57        640: 100% 5/5 [00:02<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.26it/s]
#                    all         11         44      0.501      0.571      0.474      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/70      7.11G      1.319      1.081      1.358        102        640: 100% 5/5 [00:02<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         11         44      0.713      0.565      0.581      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/70       7.1G      1.241      1.031      1.273         55        640: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.74it/s]
#                    all         11         44      0.748      0.606       0.63      0.359
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/70      7.01G      1.249     0.9881      1.264         75        640: 100% 5/5 [00:02<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         11         44      0.755       0.63      0.637      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/70      7.12G      1.349      1.102      1.322         52        640: 100% 5/5 [00:02<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.13it/s]
#                    all         11         44      0.755      0.568      0.646      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/70      7.09G      1.292      1.071      1.301        104        640: 100% 5/5 [00:02<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.80it/s]
#                    all         11         44      0.631      0.636      0.604       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/70      6.97G      1.253       1.02      1.237         76        640: 100% 5/5 [00:02<00:00,  1.87it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.93it/s]
#                    all         11         44      0.555      0.614      0.544      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/70         7G      1.149     0.9543      1.211         71        640: 100% 5/5 [00:02<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.44it/s]
#                    all         11         44      0.525      0.591      0.488      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/70      7.02G      1.209     0.9335      1.253         83        640: 100% 5/5 [00:02<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.02it/s]
#                    all         11         44      0.422      0.545        0.4      0.207
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/70      7.01G      1.265     0.9072       1.28         78        640: 100% 5/5 [00:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.36it/s]
#                    all         11         44      0.542      0.432      0.472      0.254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/70      7.09G      1.182     0.9496      1.235         93        640: 100% 5/5 [00:02<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.46it/s]
#                    all         11         44      0.541      0.568      0.539      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       51/70      7.01G      1.237     0.9372       1.25         60        640: 100% 5/5 [00:02<00:00,  2.05it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.54it/s]
#                    all         11         44      0.484      0.659      0.581       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       52/70      7.05G      1.259     0.9703      1.278         79        640: 100% 5/5 [00:02<00:00,  1.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.56it/s]
#                    all         11         44      0.678      0.669      0.696      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       53/70      6.99G      1.133     0.8626      1.205         66        640: 100% 5/5 [00:02<00:00,  1.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.88it/s]
#                    all         11         44       0.74      0.727      0.745      0.425
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       54/70         7G      1.134     0.8248       1.18         64        640: 100% 5/5 [00:02<00:00,  2.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.91it/s]
#                    all         11         44      0.767      0.749       0.72      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       55/70       7.1G      1.099     0.9103      1.227         65        640: 100% 5/5 [00:02<00:00,  1.95it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.59it/s]
#                    all         11         44      0.775      0.773      0.731      0.431
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       56/70      7.01G      1.111     0.8905      1.234         65        640: 100% 5/5 [00:02<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         11         44       0.74      0.777      0.727      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       57/70      6.98G      1.068      0.811      1.163         81        640: 100% 5/5 [00:02<00:00,  2.07it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.25it/s]
#                    all         11         44      0.756      0.795      0.727      0.437
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       58/70      6.98G      1.136     0.9049      1.238         42        640: 100% 5/5 [00:02<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.94it/s]
#                    all         11         44      0.732      0.795      0.719      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       59/70      7.02G      1.077      0.808       1.16        104        640: 100% 5/5 [00:02<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.34it/s]
#                    all         11         44      0.752      0.773      0.712      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       60/70      7.04G      1.048     0.7781      1.139         78        640: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.99it/s]
#                    all         11         44      0.755      0.727        0.7      0.432
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       61/70      7.06G      1.017      1.074      1.166         42        640: 100% 5/5 [00:04<00:00,  1.25it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.23it/s]
#                    all         11         44      0.739      0.727       0.69      0.426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       62/70      7.09G     0.9521     0.8751      1.113         30        640: 100% 5/5 [00:02<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.12it/s]
#                    all         11         44        0.7      0.705      0.693      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       63/70         7G      1.066       0.89      1.206         34        640: 100% 5/5 [00:02<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.39it/s]
#                    all         11         44      0.772      0.614      0.699      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       64/70      7.12G     0.9536      0.733      1.136         67        640: 100% 5/5 [00:02<00:00,  2.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.76it/s]
#                    all         11         44      0.818      0.613      0.704      0.465
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       65/70      6.96G     0.9472     0.7482      1.139         33        640: 100% 5/5 [00:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         11         44      0.648      0.752      0.703      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       66/70       7.1G     0.9424     0.7162      1.161         40        640: 100% 5/5 [00:02<00:00,  2.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.23it/s]
#                    all         11         44      0.656      0.737      0.708      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       67/70      7.12G     0.9227     0.6828      1.095         50        640: 100% 5/5 [00:02<00:00,  2.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.63it/s]
#                    all         11         44      0.711      0.727      0.717      0.473
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       68/70      7.12G     0.9675     0.7283      1.157         47        640: 100% 5/5 [00:02<00:00,  1.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.88it/s]
#                    all         11         44      0.707      0.712      0.722      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       69/70      7.11G     0.9611     0.6698      1.146         76        640: 100% 5/5 [00:02<00:00,  2.10it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.73it/s]
#                    all         11         44      0.725       0.72      0.724      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       70/70      6.98G     0.9667     0.6931      1.139         40        640: 100% 5/5 [00:02<00:00,  1.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.07it/s]
#                    all         11         44      0.736      0.727      0.731      0.495
#
# 70 epochs completed in 0.097 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.0MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.0MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.37it/s]
#                    all         11         44      0.735      0.727      0.732      0.495
# Speed: 0.2ms preprocess, 9.6ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}//runs/detect/train
# Out:
# args.yaml					    P_curve.png       train_batch2.jpg
# confusion_matrix_normalized.png			    PR_curve.png      train_batch300.jpg
# confusion_matrix.png				    R_curve.png       train_batch301.jpg
# events.out.tfevents.1698694063.5b4e6bf2fb2f.3488.0  results.csv       train_batch302.jpg
# F1_curve.png					    results.png       val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg  val_batch0_pred.jpg
# labels.jpg					    train_batch1.jpg  weights

# %%
# %cd {HOME}

Image(filename = f'{HOME}/runs/detect/train/confusion_matrix.png', width = 900)
# Out:
# /content

# %%
# %cd {HOME}

Image(filename = f'{HOME}/runs/detect/train/results.png', width = 600)
# Out:
# /content

# %%
# %cd {HOME}

Image(filename = f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width = 600)
# Out:
# /content

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/potholedetection/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/potholedetection/valid/labels.cache... 11 images, 0 backgrounds, 0 corrupt: 100% 11/11 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.03s/it]
#                    all         11         44      0.735      0.727      0.732      0.495
# Speed: 0.2ms preprocess, 38.8ms inference, 0.0ms loss, 17.5ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/potholedetection/test/images
# Out:
# /content
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/12 /content/drive/MyDrive/potholedetection/test/images/images41_jpg.rf.11026da73060bd1db20f3a83286d480b.jpg: 640x640 2 Potholes, 37.1ms
# image 2/12 /content/drive/MyDrive/potholedetection/test/images/images59_jpg.rf.ab0687e6f4bc51f2628866bf797b56d6.jpg: 640x640 (no detections), 37.1ms
# image 3/12 /content/drive/MyDrive/potholedetection/test/images/images74_jpg.rf.628b2f6ecbf356138c6f1b67bf7cc490.jpg: 640x640 1 Pothole, 37.1ms
# image 4/12 /content/drive/MyDrive/potholedetection/test/images/images96_jpg.rf.1d0dcb3b46980a6f1ebec5c6843943c8.jpg: 640x640 (no detections), 37.1ms
# image 5/12 /content/drive/MyDrive/potholedetection/test/images/img_0988_jpg.rf.df15ce39251c1b2c31a7c29f5441c623.jpg: 640x640 2 Potholes, 37.0ms
# image 6/12 /content/drive/MyDrive/potholedetection/test/images/img_1797_jpg.rf.83b3958fd7d895438940b39889b017fa.jpg: 640x640 (no detections), 37.0ms
# image 7/12 /content/drive/MyDrive/potholedetection/test/images/youtube-15_jpg.rf.abfd0deab7289b24a60afba818788eff.jpg: 640x640 2 Potholes, 37.1ms
# image 8/12 /content/drive/MyDrive/potholedetection/test/images/youtube-16_jpg.rf.109676222bd982a0624fe503b210f6e1.jpg: 640x640 3 Potholes, 37.0ms
# image 9/12 /content/drive/MyDrive/potholedetection/test/images/youtube-17_jpg.rf.28e3a24ae68706526389a2dd103799b1.jpg: 640x640 3 Potholes, 37.0ms
# image 10/12 /content/drive/MyDrive/potholedetection/test/images/youtube-18_jpg.rf.1f1c860ab4e3b17424b3094fd7e06c42.jpg: 640x640 10 Potholes, 37.0ms
# image 11/12 /content/drive/MyDrive/potholedetection/test/images/youtube-18_jpg.rf.4602332290f2ee72cea7ac99d448240f.jpg: 640x640 1 Pothole, 37.0ms
# image 12/12 /content/drive/MyDrive/potholedetection/test/images/youtube-18_jpg.rf.c9d130365983b426b67044c7bdc80ff1.jpg: 640x640 7 Potholes, 37.0ms
# Speed: 1.8ms preprocess, 37.0ms inference, 10.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image('/content/runs/detect/predict/images74_jpg.rf.628b2f6ecbf356138c6f1b67bf7cc490.jpg')

# %%
# %cd {HOME}

# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source='/content/drive/MyDrive/demo.mp4'
# Out:
# /content
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (1/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 124.8ms
# video 1/1 (2/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 25.8ms
# video 1/1 (3/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 25.7ms
# video 1/1 (4/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 25.7ms
# video 1/1 (5/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 25.7ms
# video 1/1 (6/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 25.7ms
# video 1/1 (7/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 25.7ms
# video 1/1 (8/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 25.7ms
# video 1/1 (9/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 24.0ms
# video 1/1 (10/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 18.6ms
# video 1/1 (11/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 19.4ms
# video 1/1 (12/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 18.5ms
# video 1/1 (13/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 18.6ms
# video 1/1 (14/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 18.5ms
# video 1/1 (15/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.2ms
# video 1/1 (16/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 15.2ms
# video 1/1 (17/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.2ms
# video 1/1 (18/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.3ms
# video 1/1 (19/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 14.8ms
# video 1/1 (20/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.8ms
# video 1/1 (21/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 17.1ms
# video 1/1 (22/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.8ms
# video 1/1 (23/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.8ms
# video 1/1 (24/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 13.4ms
# video 1/1 (25/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.6ms
# video 1/1 (26/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.4ms
# video 1/1 (27/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 13.4ms
# video 1/1 (28/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.5ms
# video 1/1 (29/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.5ms
# video 1/1 (30/324) /content/drive/MyDrive/demo.mp4: 384x640 6 Potholes, 13.5ms
# video 1/1 (31/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 22.2ms
# video 1/1 (32/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 13.2ms
# video 1/1 (33/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.3ms
# video 1/1 (34/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 16.3ms
# video 1/1 (35/324) /content/drive/MyDrive/demo.mp4: 384x640 5 Potholes, 13.3ms
# video 1/1 (36/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 16.6ms
# video 1/1 (37/324) /content/drive/MyDrive/demo.mp4: 384x640 5 Potholes, 15.0ms
# video 1/1 (38/324) /content/drive/MyDrive/demo.mp4: 384x640 5 Potholes, 13.1ms
# video 1/1 (39/324) /content/drive/MyDrive/demo.mp4: 384x640 5 Potholes, 13.1ms
# video 1/1 (40/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 13.1ms
# video 1/1 (41/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 13.1ms
# video 1/1 (42/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.1ms
# video 1/1 (43/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.1ms
# video 1/1 (44/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.2ms
# video 1/1 (45/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 17.4ms
# video 1/1 (46/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 12.9ms
# video 1/1 (47/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 15.6ms
# video 1/1 (48/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.9ms
# video 1/1 (49/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 17.1ms
# video 1/1 (50/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 12.8ms
# video 1/1 (51/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 14.9ms
# video 1/1 (52/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.8ms
# video 1/1 (53/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.3ms
# video 1/1 (54/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.8ms
# video 1/1 (55/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 16.6ms
# video 1/1 (56/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (57/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.8ms
# video 1/1 (58/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (59/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.9ms
# video 1/1 (60/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (61/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (62/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.2ms
# video 1/1 (63/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (64/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (65/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.4ms
# video 1/1 (66/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.7ms
# video 1/1 (67/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (68/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (69/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (70/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (71/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (72/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.0ms
# video 1/1 (73/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 13.3ms
# video 1/1 (74/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 13.2ms
# video 1/1 (75/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 19.7ms
# video 1/1 (76/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 13.0ms
# video 1/1 (77/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (78/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.3ms
# video 1/1 (79/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.3ms
# video 1/1 (80/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 14.1ms
# video 1/1 (81/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (82/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (83/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (84/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (85/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.8ms
# video 1/1 (86/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 16.6ms
# video 1/1 (87/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (88/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.1ms
# video 1/1 (89/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 14.9ms
# video 1/1 (90/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.9ms
# video 1/1 (91/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.9ms
# video 1/1 (92/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.7ms
# video 1/1 (93/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.6ms
# video 1/1 (94/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.2ms
# video 1/1 (95/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.2ms
# video 1/1 (96/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 18.5ms
# video 1/1 (97/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.3ms
# video 1/1 (98/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.6ms
# video 1/1 (99/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.4ms
# video 1/1 (100/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.1ms
# video 1/1 (101/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.1ms
# video 1/1 (102/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.1ms
# video 1/1 (103/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.2ms
# video 1/1 (104/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.1ms
# video 1/1 (105/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.2ms
# video 1/1 (106/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.9ms
# video 1/1 (107/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 16.0ms
# video 1/1 (108/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.5ms
# video 1/1 (109/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 15.5ms
# video 1/1 (110/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.1ms
# video 1/1 (111/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.4ms
# video 1/1 (112/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.9ms
# video 1/1 (113/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 15.7ms
# video 1/1 (114/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 15.7ms
# video 1/1 (115/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.7ms
# video 1/1 (116/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.7ms
# video 1/1 (117/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.7ms
# video 1/1 (118/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 15.6ms
# video 1/1 (119/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.2ms
# video 1/1 (120/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.2ms
# video 1/1 (121/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 16.0ms
# video 1/1 (122/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 16.6ms
# video 1/1 (123/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.4ms
# video 1/1 (124/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.5ms
# video 1/1 (125/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.4ms
# video 1/1 (126/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 21.6ms
# video 1/1 (127/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.3ms
# video 1/1 (128/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.9ms
# video 1/1 (129/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.7ms
# video 1/1 (130/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.5ms
# video 1/1 (131/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.4ms
# video 1/1 (132/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.3ms
# video 1/1 (133/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.3ms
# video 1/1 (134/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.3ms
# video 1/1 (135/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.3ms
# video 1/1 (136/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.7ms
# video 1/1 (137/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.7ms
# video 1/1 (138/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 16.7ms
# video 1/1 (139/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.8ms
# video 1/1 (140/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.5ms
# video 1/1 (141/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 17.5ms
# video 1/1 (142/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 16.9ms
# video 1/1 (143/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.0ms
# video 1/1 (144/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.1ms
# video 1/1 (145/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 17.1ms
# video 1/1 (146/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 17.1ms
# video 1/1 (147/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 18.0ms
# video 1/1 (148/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 17.1ms
# video 1/1 (149/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.9ms
# video 1/1 (150/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.9ms
# video 1/1 (151/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.8ms
# video 1/1 (152/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 14.4ms
# video 1/1 (153/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.5ms
# video 1/1 (154/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 14.5ms
# video 1/1 (155/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 13.8ms
# video 1/1 (156/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.8ms
# video 1/1 (157/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.8ms
# video 1/1 (158/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.5ms
# video 1/1 (159/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.4ms
# video 1/1 (160/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.4ms
# video 1/1 (161/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.3ms
# video 1/1 (162/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.1ms
# video 1/1 (163/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.1ms
# video 1/1 (164/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.2ms
# video 1/1 (165/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.0ms
# video 1/1 (166/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.0ms
# video 1/1 (167/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.0ms
# video 1/1 (168/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 12.4ms
# video 1/1 (169/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.3ms
# video 1/1 (170/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.0ms
# video 1/1 (171/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.4ms
# video 1/1 (172/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.3ms
# video 1/1 (173/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.3ms
# video 1/1 (174/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.3ms
# video 1/1 (175/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.3ms
# video 1/1 (176/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.3ms
# video 1/1 (177/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 12.3ms
# video 1/1 (178/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 12.3ms
# video 1/1 (179/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.8ms
# video 1/1 (180/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 12.3ms
# video 1/1 (181/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.7ms
# video 1/1 (182/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 14.4ms
# video 1/1 (183/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (184/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (185/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (186/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.6ms
# video 1/1 (187/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (188/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 11.9ms
# video 1/1 (189/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 17.5ms
# video 1/1 (190/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.8ms
# video 1/1 (191/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (192/324) /content/drive/MyDrive/demo.mp4: 384x640 4 Potholes, 12.0ms
# video 1/1 (193/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (194/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (195/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (196/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (197/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (198/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.7ms
# video 1/1 (199/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.8ms
# video 1/1 (200/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (201/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 12.6ms
# video 1/1 (202/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (203/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 17.0ms
# video 1/1 (204/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (205/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (206/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (207/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (208/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 14.7ms
# video 1/1 (209/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (210/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (211/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (212/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (213/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (214/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (215/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.5ms
# video 1/1 (216/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.6ms
# video 1/1 (217/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.5ms
# video 1/1 (218/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 13.5ms
# video 1/1 (219/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (220/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.5ms
# video 1/1 (221/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (222/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.5ms
# video 1/1 (223/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.7ms
# video 1/1 (224/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.9ms
# video 1/1 (225/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (226/324) /content/drive/MyDrive/demo.mp4: 384x640 3 Potholes, 11.5ms
# video 1/1 (227/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (228/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.7ms
# video 1/1 (229/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (230/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.6ms
# video 1/1 (231/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (232/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.6ms
# video 1/1 (233/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (234/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.6ms
# video 1/1 (235/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (236/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (237/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (238/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.9ms
# video 1/1 (239/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (240/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (241/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (242/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (243/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (244/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 15.7ms
# video 1/1 (245/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (246/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (247/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (248/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 13.6ms
# video 1/1 (249/324) /content/drive/MyDrive/demo.mp4: 384x640 2 Potholes, 11.5ms
# video 1/1 (250/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (251/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (252/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.7ms
# video 1/1 (253/324) /content/drive/MyDrive/demo.mp4: 384x640 1 Pothole, 11.5ms
# video 1/1 (254/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (255/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (256/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (257/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (258/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 13.4ms
# video 1/1 (259/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (260/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (261/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (262/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (263/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (264/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (265/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (266/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (267/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (268/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (269/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 15.2ms
# video 1/1 (270/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (271/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (272/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 14.8ms
# video 1/1 (273/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.8ms
# video 1/1 (274/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (275/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (276/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (277/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (278/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (279/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (280/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (281/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (282/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (283/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.1ms
# video 1/1 (284/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (285/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.6ms
# video 1/1 (286/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 18.9ms
# video 1/1 (287/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (288/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (289/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (290/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (291/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (292/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.7ms
# video 1/1 (293/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (294/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (295/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (296/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (297/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (298/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (299/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 17.8ms
# video 1/1 (300/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (301/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# video 1/1 (302/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (303/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.7ms
# video 1/1 (304/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (305/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (306/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (307/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 14.2ms
# video 1/1 (308/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (309/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (310/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (311/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (312/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (313/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.9ms
# video 1/1 (314/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 13.2ms
# video 1/1 (315/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (316/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (317/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 12.3ms
# video 1/1 (318/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (319/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.6ms
# video 1/1 (320/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (321/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (322/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.4ms
# video 1/1 (323/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.3ms
# video 1/1 (324/324) /content/drive/MyDrive/demo.mp4: 384x640 (no detections), 11.5ms
# Speed: 1.8ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# Input video path
save_path = '/content/runs/detect/predict2/demo.avi'

# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {save_path} -vcodec libx264 {compressed_path}")

# Show video
mp4 = open(compressed_path, 'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""<video width="640" height="480" controls>
    <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
